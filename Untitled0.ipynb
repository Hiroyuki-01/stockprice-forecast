# %%
cd /content/drive/MyDrive/Colab Notebooks/pytorchbook_samplecode/Google_Colaboratory/Chapter5/stockprice-forecast
# Out:
# /content/drive/MyDrive/Colab Notebooks/pytorchbook_samplecode/Google_Colaboratory/Chapter5/stockprice-forecast

# %%
#!git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/pytorchbook_samplecode/Google_Colaboratory/Chapter5/.git/

# %%
#!git clone https://github.com/Hiroyuki-01/stockprice-forecast.git
# Out:
# Cloning into 'stockprice-forecast'...
# warning: You appear to have cloned an empty repository.

# %%
#!git config --global user.email "hiroyuki0228n@gmail.com"
#!git config --global user.name "hiroyuki"

# %%
#mv webapp/* stockprice-forecast/

# %%
#ls
# Out:
# 5-2_stock_price.png  cos5-3.ipynb  Section5-2.ipynb  stockprice-forecast/
# cos5-2.ipynb         prices.csv    Section5-3.ipynb  webapp/

# %%
# !git add *

# %%
# !git config --global user.email "hiroyuki0228n@gmail.com"
# !git config --global user.name "hiroyuki"

# %%
# !git commit -m "Added new file."
# Out:
# [master (root-commit) 0fde209] Added new file.
#  16 files changed, 851636 insertions(+)
#  create mode 100644 Section5-2.ipynb
#  create mode 100644 Section5-3.ipynb
#  create mode 100644 cos5-2.ipynb
#  create mode 100644 cos5-3.ipynb
#  create mode 100644 prices.csv
#  create mode 100644 stockprice-forecast/Untitled0.ipynb
#  create mode 100644 stockprice-forecast/__pycache__/predict_stockprice.cpython-37.pyc
#  create mode 100644 stockprice-forecast/main.py
#  create mode 100644 stockprice-forecast/predict_stockprice.py
#  create mode 100644 stockprice-forecast/static/images/logo.png
#  create mode 100644 stockprice-forecast/static/images/stock_price_prediction_sample.png
#  create mode 100644 stockprice-forecast/static/predict_files/stock_price_prediction.png
#  create mode 100644 stockprice-forecast/static/train_files/net.pth
#  create mode 100644 stockprice-forecast/static/train_files/scaler.pkl
#  create mode 100644 stockprice-forecast/templates/get.html
#  create mode 100644 stockprice-forecast/templates/post.html

# %%
# !git push origin master
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git remote add origin https://github.com/Hiroyuki-01/stockprice-forecast.git

# %%
# !git remote set-url origin https://Hiroyuki-01:e32btc9w@github.com/Hiroyuki-01/stockprice-forecast.git

# %%
# !mkdir -p drive/MyDrive/.ssh
# !ssh-keygen -t rsa -f drive/MyDrive/.ssh/id_rsa_github
# Out:
# Generating public/private rsa key pair.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in drive/MyDrive/.ssh/id_rsa_github.
# Your public key has been saved in drive/MyDrive/.ssh/id_rsa_github.pub.
# The key fingerprint is:
# SHA256:GSVCwcDNv2ezdlHzNr6/Pau044niY6Q8OlnAuSbxy3o root@f42cde33124b
# The key's randomart image is:
# +---[RSA 2048]----+
# |   ..*+.. .      |
# |    . +. o       |
# |    . ...        |
# |   . +  .o    o  |
# |    o o S.   . o |
# |   . + ...+ .  .o|
# |    + = oo o o...|
# |     E + +o +.oo.|
# |   .o.o +ooo.=o+O|
# +----[SHA256]-----+

# %%
# !cat drive/MyDrive/.ssh/id_rsa_github.pub
# Out:
# ssh-rsa  root@f42cde33124b

# %% [markdown]
# https://qiita.com/SeeLog/items/100e64e2decd0c0efb7d

# %%
# %env TOKEN=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
# Out:
# env: TOKEN=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

# %%
# !git remote remove origin

# %%
# !git remote add origin https://$$TOKEN@github.com/Hiroyuki-01/stockprice-forecast.git

# %% [markdown]
# Google ColabでGithubから非公開リポジトリをcloneする
# https://zenn.dev/e4exp/articles/a4f6acab34fa48
#
# 個人アクセストークンを使用する
# https://docs.github.com/ja/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token#creating-a-token

# %%
# !git push origin master
# Out:
# Counting objects: 25, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (25/25), done.
# Writing objects: 100% (25/25), 15.30 MiB | 3.29 MiB/s, done.
# Total 25 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/Hiroyuki-01/stockprice-forecast.git
#  * [new branch]      master -> master

# %%
# !ls
# Out:
# cos5-2.ipynb  drive	  Section5-2.ipynb  stockprice-forecast
# cos5-3.ipynb  prices.csv  Section5-3.ipynb
