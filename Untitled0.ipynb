# %%
cd /content/drive/MyDrive/Colab Notebooks/pytorchbook_samplecode/Google_Colaboratory/Chapter5/stockprice-forecast
# Out:
# /content/drive/MyDrive/Colab Notebooks/pytorchbook_samplecode/Google_Colaboratory/Chapter5/stockprice-forecast

# %%
#!git init

# %%
#!git clone https://github.com/Hiroyuki-01/stockprice-forecast.git

# %%
#!git config --global user.email "hiroyuki0228n@gmail.com"
#!git config --global user.name "hiroyuki"

# %%
#mv webapp/* stockprice-forecast/

# %%
#ls

# %%
# !git add *

# %%
# !git config --global user.email "hiroyuki0228n@gmail.com"
# !git config --global user.name "hiroyuki"

# %%
# !git commit -m "Added new file."
# Out:
# [master 2feb40f] Added new file.
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (68%)

# %% [markdown]
# https://qiita.com/SeeLog/items/100e64e2decd0c0efb7d

# %%
# %env TOKEN=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
# Out:
# env: TOKEN=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

# %%
# !git remote remove origin

# %%
# !git remote add origin https://$$TOKEN@github.com/Hiroyuki-01/stockprice-forecast.git

# %% [markdown]
# Google ColabでGithubから非公開リポジトリをcloneする
# https://zenn.dev/e4exp/articles/a4f6acab34fa48
#
# 個人アクセストークンを使用する
# https://docs.github.com/ja/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token#creating-a-token

# %%
# !git push origin master
# Out:
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (9/9), 6.74 KiB | 690.00 KiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# To https://github.com/Hiroyuki-01/stockprice-forecast.git
#    7399f82..2feb40f  master -> master

# %%
# !ls
# Out:
# main.py		       __pycache__	 static
# predict_stockprice.py  requirements.txt  templates
# Procfile	       runtime.txt	 Untitled0.ipynb

# %% [markdown]
# 必要ファイルを作成

# %%
# !pip install gunicorn

# %%
# !pip freeze -l > requirements.txt

# %%
# !echo "web: gunicorn main:app --log-file -" > Procfile

# %%
# !echo "python-3.10.0" > runtime.txt

# %%
rm requirements.gdoc

# %%
ls -al
# Out:
# total 43
# drwx------ 8 root root  4096 Oct 27 14:40 .git/
# -rw------- 1 root root  1119 Jul 22  2020 main.py
# -rw------- 1 root root  3911 Nov 17  2020 predict_stockprice.py
# -rw------- 1 root root    36 Oct 27 14:15 Procfile
# drwx------ 2 root root  4096 Oct  6 06:32 __pycache__/
# -rw------- 1 root root  7312 Oct 27 14:40 requirements.txt
# -rw------- 1 root root    14 Oct 27 14:31 runtime.txt
# drwx------ 5 root root  4096 Jul 17  2020 static/
# drwx------ 2 root root  4096 Jul 16  2020 templates/
# -rw------- 1 root root 12920 Oct 27 14:40 Untitled0.ipynb

# %%
# !git add .

# %%
# !git commit -m 'Heroku'
# Out:
# [master 05ca26b] Heroku
#  2 files changed, 7 insertions(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (65%)

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 893 bytes | 446.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Hiroyuki-01/stockprice-forecast.git
#    645ccbd..05ca26b  master -> master
